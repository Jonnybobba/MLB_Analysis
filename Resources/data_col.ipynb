# %%
import pandas as pd
import matplotlib as plt

# %% [markdown]
# ### Batter Data -- Basic

# %%
mlb_2020_batter_base = pd.read_csv("batter_data/basic/mlb_2020_batter_base.csv")
mlb_2019_batter_base = pd.read_csv("batter_data/basic/mlb_2019_batter_base.csv")
mlb_2018_batter_base = pd.read_csv("batter_data/basic/mlb_2018_batter_base.csv")
mlb_career_batter = pd.read_csv("batter_data/Batting.csv")
mlb_career_batter
# Out:
#          playerID  yearID  stint teamID lgID   G   AB   R   H  2B  ...   RBI  \
# 0       abercda01    1871      1    TRO  NaN   1    4   0   0   0  ...   0.0
# 1        addybo01    1871      1    RC1  NaN  25  118  30  32   6  ...  13.0
# 2       allisar01    1871      1    CL1  NaN  29  137  28  40   4  ...  19.0
# 3       allisdo01    1871      1    WS3  NaN  27  133  28  44  10  ...  27.0
# 4       ansonca01    1871      1    RC1  NaN  25  120  29  39  11  ...  16.0
# ...           ...     ...    ...    ...  ...  ..  ...  ..  ..  ..  ...   ...
# 108784  zimmebr02    2020      1    BAL   AL   2    0   0   0   0  ...   0.0
# 108785  zimmejo02    2020      1    DET   AL   3    0   0   0   0  ...   0.0
# 108786  zimmeky01    2020      1    KCA   AL  16    0   0   0   0  ...   0.0
# 108787  zuberty01    2020      1    KCA   AL  23    0   0   0   0  ...   0.0
# 108788  zuninmi01    2020      1    TBA   AL  28   75   8  11   4  ...  10.0
#
# ...

# %% [markdown]
# mlb_2019_batter_base

# %%
mlb_2018_batter_base
# Out:
#                Player Team Pos  Age    G   AB    R    H  2B  3B  ...  CS  BB  \
# 0         Trea Turner  WAS  SS   27  162  664  103  180  27   6  ...   9  69
# 1    Francisco Lindor  CLE  SS   27  158  661  129  183  42   2  ...  10  70
# 2        Ozzie Albies  ATL  2B   24  158  639  105  167  40   5  ...   3  36
# 3         Jose Peraza  CIN  2B   26  157  632   85  182  31   4  ...   6  29
# 4       Marcus Semien  OAK  SS   30  159  632   89  161  35   2  ...   6  61
# ..                ...  ...  ..  ...  ...  ...  ...  ...  ..  ..  ...  ..  ..
# 684  Aristides Aquino  CIN  OF   26    1    1    0    0   0   0  ...   0   0
# 685     Juan Graterol  LAA   C   31    1    1    0    1   0   0  ...   0   0
# 686     Chris Stewart  ARI   C   38    3    1    0    0   0   0  ...   0   0
# 687   Justin Williams   TB  OF   25    1    1    0    0   0   0  ...   0   0
# 688      Mike Freeman  CHC  2B   33    1    0    0    0   0   0  ...   0   0
#
# ...

# %%
# Need to fix retired players, and collect into one DataFrame

# %% [markdown]
# ### Batter Data -- Adv

# %%
mlb_2020_batter_adv = pd.read_csv("batter_data/advanced/mlb_2020_batter_adv.csv")
mlb_2019_batter_adv = pd.read_csv("batter_data/advanced/mlb_2019_batter_adv.csv")
mlb_2018_batter_adv = pd.read_csv("batter_data/advanced/mlb_2018_batter_adv.csv")
mlb_2020_batter_adv
# Out:
#                Player Team Pos   G   AB  P/PA  Bunts  GIDP  IBB  BB  ...  \
# 0     Whit Merrifield   KC  2B  60  248  3.76      4     3    0  12  ...
# 1          Jose Abreu  CWS  1B  60  240  3.91      0    10    1  18  ...
# 2      Dansby Swanson  ATL  SS  60  237  4.00      1     0    0  22  ...
# 3    Francisco Lindor  CLE  SS  60  236  4.20      6     8    2  24  ...
# 4        Trevor Story  COL  SS  59  235  3.99      1     5    1  24  ...
# ..                ...  ...  ..  ..  ...   ...    ...   ...  ...  ..  ...
# 606    Scott Schebler  ATL  OF   1    1  3.00      0     0    0   0  ...
# 607  Aaron Whitefield  MIN  OF   3    1  1.00      0     0    0   0  ...
# 608     Luis Gonzalez  CWS  OF   3    1  2.50      0     0    0   0  ...
# 609        Greg Allen   SD  OF   1    1  3.00      0     0    0   2  ...
# 610   Yermin Mercedes  CWS   C   1    1  6.00      0     0    0   0  ...
#
#      BB/K    CT%  SBO%    AVG  BABIP   wOBA    GB%   LD%   FB%  HR/FB%
# ...

# %%
mlb_2019_batter_adv
# Out:
#                Player Team Pos    G   AB  P/PA  Bunts  GIDP  IBB  BB  ...  \
# 0     Whit Merrifield   KC  2B  162  681  3.77     17     8    5  45  ...
# 1       Marcus Semien  OAK  SS  162  657  3.97      3    11    2  87  ...
# 2       Rafael Devers  BOS  3B  156  647  3.75      6     8    7  48  ...
# 3     Jonathan Villar  BAL  2B  162  642  3.98     27     8    0  61  ...
# 4        Ozzie Albies  ATL  2B  160  640  3.54      5     2    6  54  ...
# ..                ...  ...  ..  ...  ...   ...    ...   ...  ...  ..  ...
# 688       Jose Rondon  BAL  2B    1    1  5.00      0     0    0   0  ...
# 689   Travis d'Arnaud  LAD   C    1    1  2.00      0     0    0   0  ...
# 690     Aaron Altherr   SF  OF    1    1  6.00      0     0    0   0  ...
# 691       Rob Brantly  PHI   C    1    1  3.00      0     0    0   0  ...
# 692  John Ryan Murphy  ATL   C    1    1  3.00      0     0    0   0  ...
#
#      BB/K    CT%  SBO%    AVG  BABIP   wOBA   GB%   LD%   FB%  HR/FB%
# ...

# %%
mlb_2018_batter_adv
# Out:
#                Player Team Pos    G   AB  P/PA  Bunts  GIDP  IBB  BB  ...  \
# 0         Trea Turner  WAS  SS  162  664  3.95     28     7    3  69  ...
# 1    Francisco Lindor  CLE  SS  158  661  3.91     11     5    7  70  ...
# 2        Ozzie Albies  ATL  2B  158  639  3.48     21     9    0  36  ...
# 3         Jose Peraza  CIN  2B  157  632  3.36     38    12    4  29  ...
# 4       Marcus Semien  OAK  SS  159  632  4.10      3    12    1  61  ...
# ..                ...  ...  ..  ...  ...   ...    ...   ...  ...  ..  ...
# 683  Aristides Aquino  CIN  OF    1    1  5.00      0     0    0   0  ...
# 684     Juan Graterol  LAA   C    1    1  1.00      0     0    0   0  ...
# 685     Chris Stewart  ARI   C    3    1  3.00      0     0    0   0  ...
# 686   Justin Williams   TB  OF    1    1  4.00      0     1    0   0  ...
# 687      Mike Freeman  CHC  2B    1    0  3.00      1     0    0   0  ...
#
#      BB/K    CT%  SBO%    AVG  BABIP   wOBA    GB%   LD%   FB%  HR/FB%
# ...

# %%
# # Need to fix retired players, and collect into one DataFrame
